# %%
import pandas as pd
import datetime

# start, end, week_topics, prelectures, surveys, homeworks, general, conflicts, and exams ...
# ... are the only things that need to be updated.
# After making changes to these variables, run all code blocks.
# Once "pyperclip.copy(doc)" is run, head over to "calendar.html" in the "_includes" folder and ...
# ... select and remove all of the existing text, and then paste - you will see a new, full body ...
# ... of html code for the calendar.

# Note: Pyperclip will need to be installed on the computer in order to use. Head to ...
# ... https://pypi.org/project/pyperclip/ 
# Or type: "pip install pyperclip" into terminal.

# Enter first day of class and last day of finals.
# these dates will be automatically expanded to the first Monday and Last Friday ...
# ... (if given dates are not the first monday or last friday respectively). 
# This makes full weeks for the beginning and end of calendar.
start = '2020-08-24'
end = '2020-12-18'

# week_topics does not come with automatic bold formating. However, the line spacing below bolded elements are automatic.
# All values in prelectures, surveys, homeworks, general, conflicts, and exams dictionaries are automatically formatted.
week_topics = {
    1: "<b>Week 1: Chapter 1</b>(Controlled Experiments)",
    2: "<b>Week 2: Chapters 2-3</b>(Observational Studies)",
    3: "<b>Week 3: Chapters 3-5</b>(Histograms, Avg, Median, SD, & Normal Curve)",
    4: "<b>Week 4: Exam Week</b>",
    5: "<b>Week 5: Chapters 6-7</b>(Boxplots & Correlation)",
    6: "<b>Week 6: Chapters 8-10</b>(Regression & RMSE)",
    7: "<b>Week 7: Chapters 11-12</b>(Probability)",
    8: "<b>Week 8: Exam Week</b>",
    9: "<b>Week 9: Chapters 13-15</b>(EV, SE, & Random Variables)",
    10: "<b>Week 10: Chapters 15-16</b>(Box Models & Probability Histograms)",
    11: "<b>Week 11: Chapters 17-19</b>(Sampling & Inference)",
    12: "<b>Week 12: Exam Week</b>",
    13: "<b>Week 13: Chapters 20-22</b>(Hypothesis Testing: Z & t Tests)",
    14: "<b>Week 14: Fall Break</b>",
    15: "<b>Week 15: Chapters 22-24</b>(Hypothesis Testing: Chi Square Tests)",
    16: "<b>Week 16: Last Week of Class</b>(Final Exam Review)",
    17: "<b>Week 17: Finals Week</b>"
}

prelectures = {
    '2020-08-28': 'Chapter 1 Prelecture Due',
    '2020-09-02': 'Chapter 2 Part 1 Prelecture Due',
    '2020-09-04': 'Chapter 2 Part 2 Prelecture Due',
    '2020-09-08': 'Chapter 3 Prelecture Due',
    '2020-09-10': 'Chapter 4 Prelecture Due',
    '2020-09-14': 'Chapter 5 Prelecture Due',
    '2020-09-23': 'Chapter 7 Prelecture Due',
    '2020-09-30': 'Chapter 8 Prelecture Due',
    '2020-10-02': 'Chapter 9 Prelecture Due',
    '2020-10-05': 'Chapter 10 Prelecture Due',
    '2020-10-07': 'Chapter 11 Prelecture Due',
    '2020-10-12': 'Chapter 12 Prelecture Due',
    '2020-10-21': 'Chapter 13 Prelecture Due',
    '2020-10-23': 'Chapter 14 Prelecture Due',
    '2020-10-28': 'Chapter 15 Prelecture Due',
    '2020-10-30': 'Chapter 16 Prelecture Due',
    '2020-11-04': 'Chapter 17 Prelecture Due',
    '2020-11-06': 'Chapter 18 Prelecture Due',
    '2020-11-18': 'Chapter 20 Prelecture Due',
    '2020-11-20': 'Chapter 21 Prelecture Due',
    '2020-12-01': 'Chapter 22 Prelecture Due',
    '2020-12-03': 'Chapter 23 Part 1 Prelecture Due',
    '2020-12-08': 'Chapter 23 Part 2 Prelecture Due'
}
surveys = {
    '2020-08-28': 'Bonus Survey 1 Due',
    '2020-09-11': 'Bonus Survey 2 Due',
    '2020-10-09': 'Bonus Survey 3 Due',
    '2020-11-06': 'Bonus Survey 4 Due',
    '2020-12-10': 'Bonus Survey 5 Due (11:59pm)'
}
homeworks = {
    '2020-09-01': 'HW Assignment 1 Due',
    '2020-09-03': 'HW Assignment 2 Due',
    '2020-09-09': 'HW Assignment 3 Due',
    '2020-09-11': 'HW Assignment 4 Due',
    '2020-09-15': 'HW Assignment 5 Due',
    '2020-09-24': 'HW Assignment 6 Due',
    '2020-09-29': 'HW Assignment 7 Due',
    '2020-10-01': 'HW Assignment 8 Due',
    '2020-10-06': 'HW Assignment 9 Due',
    '2020-10-08': 'HW Assignment 10 Due',
    '2020-10-13': 'HW Assignment 11 Due',
    '2020-10-22': 'HW Assignment 12 Due',
    '2020-10-27': 'HW Assignment 13 Due',
    '2020-10-29': 'HW Assignment 14 Due',
    '2020-11-04': 'HW Assignment 15 Due',
    '2020-11-06': 'HW Assignment 16 Due',
    '2020-11-10': 'HW Assignment 17 Due',
    '2020-11-19': 'HW Assignment 18 Due',
    '2020-12-02': 'HW Assignment 19 Due',
    '2020-12-04': 'HW Assignment 20 Due',
    '2020-12-08': 'HW Assignment 21 Due',
    '2020-12-10': 'HW Assignment 22 Due'
}
general = {
#     Spring Holidays
    '2020-01-20': 'Martin Luther King Jr. Day',
    '2020-02-14': "Valentine's Day &#128152;",
    '2020-02-17': "President's Day &#127482;&#127480;",
#     Fall Holidays
    '2020-09-07': 'Labor Day <a href="{{ site.data.info.rickroll }}">⛏️</a>',
    '2020-10-31': "Halloween 🎃",
    '2020-11-01': "Day of the Dead 💀",
    '2020-11-11': "Veteran's Day",
    '2020-11-03': 'Election Day',
#     Break
    '2020-11-23': '---',
    '2020-11-24': '---',
    '2020-11-25': 'FALL BREAK <a href="{{ site.data.info.rickroll }}">🍂</a>',
    '2020-11-26': '---',
    '2020-11-27': '---',
#     Other
    '2020-08-24': 'First Day of Classes!',
    '2020-12-09': "Last Day of Classes!",
    '2020-12-10': '<b>Reading Day</b>',
    '2020-12-18': '<b>WINTER BREAK!!! <a href="{{ site.data.info.rickroll }}">❄️</a> </b><br>Have a wonderful break!'
}
conflicts = {
    '2020-09-14': 'Exam 1 Conflict Sign-Up Due',
    '2020-10-12': 'Exam 2 Conflict Sign-Up Due',
    '2020-11-09': 'Exam 3 Conflict Sign-Up Due'
}
exams = {
    '2020-09-16': 'Exam 1 at 6pm',
    '2020-10-14': 'Exam 2 at 6pm',
    '2020-11-11': 'Exam 3 at 6pm',
    '2020-12-14': 'Final Exam from 1:30-4:30pm'
}

# %%
start = datetime.datetime.strptime(start, '%Y-%m-%d')
print("start: " + str(start.date()) + " (" + start.strftime("%a") + ")")
end = datetime.datetime.strptime(end, '%Y-%m-%d')
print("end: " + str(end.date()) + " (" + end.strftime("%a") + ")")

while start.weekday() != 0:
    start += datetime.timedelta(-1)
print("extended start: " + str(start.date()) + " (" + start.strftime("%a") + ")")
while end.weekday() != 4:
    end += datetime.timedelta(1)
print("extended end: " + str(end.date()) + " (" + end.strftime("%a") + ")")
# Out:
# start: 2020-08-24 (Mon)
# end: 2020-12-18 (Fri)
# extended start: 2020-08-24 (Mon)
# extended end: 2020-12-18 (Fri)

# %%
dtrange = pd.date_range(start = start, end = end, freq = 'B')

cal = pd.DataFrame(dtrange)

cal.insert(1, 'month', dtrange.strftime("%B"))
cal.insert(2, 'day', dtrange.strftime("%a"))

week = []
for i in range(0,cal.shape[0]):
    week.append(int(i/5)+1)

cal.insert(3, 'week', pd.Series(week))

l = []
for week in range(1, cal['week'].nunique()+1):
    l.append(cal[cal['week'] == week]['month'].mode()[0])
    
block = []
for week in cal['week']:
    block.append(l[week-1])

cal.insert(4, 'block', pd.Series(block))

# def print_full(x):
#     pd.set_option('display.max_rows', len(x))
#     print(x)
#     pd.reset_option('display.max_rows')

# print(cal.shape)
# print_full(cal)

# %%
# 6 categories to check
# Priority levels:
#     1. Exams
#     2. Conflicts
#     3. Homeworks
#     4. Prelectures
#     5. Surveys
#     6. General

doc = '<div class="table-responsive">\n'
head = ('<tr>\n'+
        '  <th>Week</th>\n'+
        '  <th>Mon</th>\n'+
        '  <th>Tues</th>\n'+
        '  <th>Wed</th>\n'+
        '  <th>Thurs</th>\n'+
        '  <th>Fri</th>\n'+
        '</tr>')

for block in cal['block'].value_counts()[cal['block'].unique()].index.tolist():
#     print('<h1>' + block + '</h1>')
    doc += '<h3 style="text-align: center;">' + block + '</h3>'
    doc += '\n<div class="heading-underline"></div>'
    doc +=  '\n<table class="table table-bordered">'
#     print(head)
    doc += '\n' + head + '\n'
    sub1 = cal[cal['block'] == block]
    for week in sub1['week'].value_counts()[sub1['week'].unique()].index.tolist():
        sub2 = sub1[sub1['week'] == week]
        date = ''
        content = ''
        date += '<tr>\n  <td style="line-height:1px;margin:0;"></td>'
        content += '\n<tr>' + '\n  <td>' + str(week_topics.get(week)) + '</td>'
        for day in sub2[0]:
            events = []
            date += '\n  <td><p class="date">' + str(day.strftime("%d")) + '</p></td>'
            if (exams.get(str(day.date())) != None):
                events.append('<b><p class="exam">' + exams.get(str(day.date())) + '</p></b>')
            if (conflicts.get(str(day.date())) != None):
                events.append('<b><p class="conf">' + conflicts.get(str(day.date())) + '</p></b>')
            if (homeworks.get(str(day.date())) != None):
                events.append('<p class="hw">' + homeworks.get(str(day.date())) + '</p>')
            if (prelectures.get(str(day.date())) != None):
                events.append('<p class="prel">' + prelectures.get(str(day.date())) + '</p>')
            if (surveys.get(str(day.date())) != None):
                events.append('<p class="surv">' + surveys.get(str(day.date())) + '</p>')
            if (general.get(str(day.date())) != None):
                events.append('<p>' + general.get(str(day.date())) + '</p>')
            if len(events) > 1:
                content += '\n  <td>'
                n=0
                for event in events:
                    content += event
                content += '</td>'
            elif len(events) == 1:
                content += '\n  <td>' + events[0] + '</td>'
            elif len(events) == 0:
                content += '\n  <td></td>'
        content += '\n</tr>'
        date += '\n</tr>'
        doc += date + content
        doc += '\n'
#         print(date, content)
#     print('\n')
    doc += '</table>\n\n'
doc += '</div>'
# print(doc)

# %%
# pyperclip is needed for easier copy to clipboard
# pip install pyperclip
import pyperclip
pyperclip.copy(doc)
